# %%
# !pip install pytorch-lightning ray[tune]
# Out:
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: ray[tune] in /opt/conda/lib/python3.10/site-packages (2.24.0)
# Requirement already satisfied: torch>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (8.1.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (3.15.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (4.22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (1.0.8)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (3.20.3)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (2.2.2)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from ray[tune]) (16.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from pyarrow>=6.0.1->ray[tune]) (1.26.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[tune]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[tune]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[tune]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray[tune]) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray[tune]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray[tune]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray[tune]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray[tune]) (2024.8.30)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)

# %%
# !pip install -U ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (7.7.1)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 4.0 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 10.4 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 55.4 MB/s eta 0:00:00:00:01
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.9
#     Uninstalling widgetsnbextension-3.6.9:
#       Successfully uninstalled widgetsnbextension-3.6.9
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.11
#     Uninstalling jupyterlab_widgets-3.0.11:
#       Successfully uninstalled jupyterlab_widgets-3.0.11
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
import os
FILE_NAMES = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        FILE_NAMES.append(os.path.join(dirname, filename))

# %%
# print(FILE_NAMES)

# %%
# import torch
# torch.cuda.is_available()

# %%
# !nvidia-smi

# %%
import os
from pathlib import Path
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Dataset
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import LearningRateMonitor, EarlyStopping
from ray.tune.integration.pytorch_lightning import TuneReportCheckpointCallback
from ray import train, tune
from ray.tune import Tuner, with_resources
# from ray_lightning.tune import TuneReportCallback
from ray.train import RunConfig

# %%
# Set global parameters
scale_factor = 11.888623072966611
input_dim = 3072
# sample_rate = 0.1 # 10% of data
sample_size = 8192 # file_size * sample_rate
num_epochs = 3  # Only one epoch over all data

# Dataset with Subsampling
class ActivationDataset(Dataset):
    def __init__(self, f_type, test_fraction=0.01, scale_factor=1.0, batch_size=2048, seed=42):
        self.test_fraction = test_fraction
        self.scale_factor = scale_factor
        self.batch_size = batch_size
        self.multi = sample_size // batch_size
        self.seed = seed
        self.file_names = FILE_NAMES
        if f_type not in ["train", "test"]:
            raise ValueError("f_type must be 'train' or 'test'")
        if f_type == "train":
            self.file_names = self.file_names[:int(len(self.file_names)*(1 - self.test_fraction))]
        else:
            self.file_names = self.file_names[int(len(self.file_names)*(1 - self.test_fraction)):]
        self.f_type = f_type

    def __len__(self):
        return len(self.file_names)*self.multi

    def __getitem__(self, idx):
        # Load a single file
        f_ix = idx // self.multi # sample the file 4 times
        file_path = self.file_names[f_ix]
        activations = np.load(file_path)[:, :-3]  # Remove metadata columns

        # Normalize
        activations = activations / self.scale_factor * np.sqrt(activations.shape[1])

        # Random subsampling to sample_size
        np.random.seed(self.seed + idx)  # Change seed per file for reproducibility
        subsample_indices = np.random.choice(activations.shape[0], sample_size, replace=False)
        activations = activations[subsample_indices]

        # Get batch 
        batch_i = idx % self.multi
        start = batch_i*self.batch_size
        end = (batch_i+1)*self.batch_size
        activations = activations[start:end]

        # Convert to tensor
        return torch.tensor(activations, dtype=torch.float32)

# Model Definition
class SparseAutoencoder(pl.LightningModule):
    def __init__(self, input_dim, hidden_dim, l1_lambda, lr):
        super().__init__()
        self.save_hyperparameters()
        self.encoder = nn.Linear(input_dim, hidden_dim)
        self.decoder = nn.Linear(hidden_dim, input_dim)
        self.criterion = nn.MSELoss()
        self.l1_lambda = l1_lambda
        self.lr = lr

    def forward(self, x):
        encoded = torch.relu(self.encoder(x))
        decoded = self.decoder(encoded)
        return decoded, encoded

    def compute_loss(self, batch, decoded, encoded):
        mse_loss = self.criterion(decoded, batch)
        decoder_weight_norms = torch.norm(self.decoder.weight, p=2, dim=0)
        l1_terms = encoded * decoder_weight_norms.unsqueeze(0)
        l1_loss = torch.mean(torch.sum(l1_terms, dim=1))
        return mse_loss, l1_loss

    def training_step(self, batch, batch_idx):
        batch = batch.to("cuda")
        decoded, encoded = self(batch)
        mse_loss, l1_loss = self.compute_loss(batch, decoded, encoded)
        total_loss = mse_loss + self.l1_lambda * l1_loss

        # Compute active features
        active_features = (encoded > 0).any(dim=0).float().mean().item() * 100

        # Log metrics
        self.log("train_loss", total_loss, on_step=True, on_epoch=True)
        self.log("train_mse_loss", mse_loss, on_step=True, on_epoch=True)
        self.log("train_l1_loss", l1_loss, on_step=True, on_epoch=True)
        self.log("active_features", active_features, on_step=True, on_epoch=True)
        self.log("val_loss", 0, on_step=True, on_epoch=True)
        # train.report({"loss": total_loss, "active_features": active_features})
        return total_loss

    def validation_step(self, batch, batch_idx):
        batch = batch.to("cuda")
        decoded, encoded = self(batch)
        mse_loss, l1_loss = self.compute_loss(batch, decoded, encoded)
        total_loss = mse_loss + self.l1_lambda * l1_loss

        # Compute active features
        active_features = (encoded > 0).any(dim=0).float().mean().item() * 100

        # Log metrics
        self.log("val_loss", total_loss, on_step=False, on_epoch=True)
        self.log("val_mse_loss", mse_loss, on_step=False, on_epoch=True)
        self.log("val_l1_loss", l1_loss, on_step=False, on_epoch=True)
        self.log("val_active_features", active_features, on_step=False, on_epoch=True)
        print("RESULTS: ", total_loss, mse_loss, l1_loss, active_features)

    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters(), lr=self.lr)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
        return {"optimizer": optimizer, "lr_scheduler": scheduler}

# DataLoader Creation
def create_data_loaders(batch_size):
    train_dataset = ActivationDataset("train", 0.01, scale_factor, batch_size, 42)
    val_dataset = ActivationDataset("test", 0.01, scale_factor, batch_size, 42)
    # train_loader = DataLoader(train_dataset, batch_size=1, shuffle=False)#, num_workers=3, pin_memory=True, persistent_workers=True)
    # val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
    train_loader = DataLoader(
        train_dataset,
        batch_size=1,  # Keep 1 as outer batch size for per-file sampling
        shuffle=False,
        num_workers=3,  # Adjust based on CPU availability
        pin_memory=False,
        persistent_workers=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=1,
        shuffle=False,
        num_workers=1,  # Smaller for validation
        pin_memory=False,
    )
    return train_loader, val_loader

# Training Function with Ray Tune
def train_model(config):
    train_loader, val_loader = create_data_loaders(config["HB"]["batch_size"])
    model = SparseAutoencoder(input_dim, hidden_dim=config["HB"]["hidden_dim"], l1_lambda=config["l1_lambda"], lr=config["lr"])

    logger = TensorBoardLogger("tb_logs", name="SparseAutoencoder")

    trainer = pl.Trainer(
        max_epochs=num_epochs,
        accelerator="gpu" if torch.cuda.is_available() else "cpu",
        logger=logger,
        profiler="advanced",
        # val_check_interval=0.25,  # Check validation 4 times per epoch
        # max_time="00:30:00",  # Stop after 30 minutes
        enable_progress_bar=True, # Show progress bar
        callbacks=[
            LearningRateMonitor(logging_interval="step"),
            EarlyStopping(monitor="val_loss", patience=3, mode="min"),
            TuneReportCheckpointCallback(
                {
                    "train_loss": "train_loss",
                    "train_mse_loss": "train_mse_loss",
                    "train_l1_loss": "train_l1_loss",
                    "active_features": "active_features",
                    "val_loss": "val_loss",
                },
                filename="none",  # Do not save checkpoints
                save_checkpoints = False,
                on="train_batch_end",
            ),
            TuneReportCheckpointCallback(
                {
                    "val_loss": "val_loss",
                    "val_mse_loss": "val_mse_loss",
                    "val_l1_loss": "val_l1_loss",
                    "val_active_features": "val_active_features",
                },
                filename="none1",
                save_checkpoints = False,
                on="validation_end",
            ),
            # RayTrainReportCallback(),
        ],
        # strategy=RayDDPStrategy(), # Use Ray for distributed training, DDP stands for Distributed Data Parallel
        # callbacks=[RayTrainReportCallback()], # Report metrics to Ray
        # plugins=[RayLightningEnvironment()], # Use Ray for distributed training
    )
    trainer.fit(model, train_loader, val_loader)

# Ray Tune Hyperparameter Search
def tune_hyperparameters():

    # possible_hidden_dims = [4096, 8192, 16384, 20000, 32768]
    possible_batch_sizes = [2048, 4096, 8192]
    possible_hidden_dims = [20000, 32768, 65536]
    # possible_batch_sizes = [1024, 2048, 4096, 8192]
    # possible_hidden_dims = [20000]
    # possible_batch_sizes = [8192]

    valid_hb_pairs = []
    for hidden_dim in possible_hidden_dims:
        for batch_size in possible_batch_sizes:
            if hidden_dim * batch_size <= 441_000_000: # VRAM limit
                valid_hb_pairs.append({"hidden_dim": hidden_dim, "batch_size": batch_size})


    # search_space = {
    #     "hidden_dim": tune.choice([4096, 8192, 16384, 20000, 32768]),
    #     "batch_size": tune.choice([512, 1024, 2048, 4096, 8192]),
    #     "l1_lambda": tune.loguniform(1e-4, 1e-2),
    #     "lr": tune.loguniform(1e-4, 1e-2),
    # }

    search_space = {
        "HB": tune.choice(valid_hb_pairs),
        "lr": tune.loguniform(1e-5, 1e-1),
        "l1_lambda": tune.loguniform(1e-3, 1e-1),
    }

    # search_space = {
    #     "HB": tune.choice(valid_hb_pairs),
    #     "l1_lambda": tune.choice([0.01]),
    #     "lr": tune.choice([0.0001]),
    # }

    scheduler_asha = tune.schedulers.ASHAScheduler(
        time_attr="training_iteration",
        metric="train_loss",
        mode="min",
        max_t=80,
        grace_period=40, # at least 25 batches
        reduction_factor=2,
    )

    # os.environ["RAY_CHDIR_TO_TRIAL_DIR"] = "0" # Allows relative paths, but trials are not isolated

    trainable_with_resources = with_resources(
        train_model,
        {"cpu": 4, "gpu": 1}  # Adjust based on your available resources
    )

    tuner = Tuner(
        trainable=trainable_with_resources,
        param_space=search_space,
        tune_config=tune.TuneConfig(
            num_samples=20, # Number of hyperparameter sets to try
            max_concurrent_trials=3, # Number of trials to run concurrently
            scheduler=scheduler_asha,
        ),
        run_config=RunConfig(
            name="hyperparameter_search",
            storage_path=str(Path("./results").resolve()),
        ),
    )
    results = tuner.fit()
    best_result = results.get_best_result(metric="val_loss", mode="min")
    print("Best Hyperparameters Found:")
    print(best_result.config)
    return results

# # Run Hyperparameter Search
# if __name__ == "__main__":
#     tune_hyperparameters()

# %%
import multiprocessing
multiprocessing.set_start_method("spawn", force=True)

# %%
results = tune_hyperparameters()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-04 14:04:05</td></tr>
# <tr><td>Running for: </td><td>01:10:02.29        </td></tr>
# <tr><td>Memory:      </td><td>4.2/31.4 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=20<br>Bracket: Iter 80.000: -0.8739008903503418 | Iter 40.000: -0.9672983288764954<br>Logical resource usage: 4.0/4 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:P100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc            </th><th>HB                  </th><th style="text-align: right;">  l1_lambda</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  train_mse_loss</th><th style="text-align: right;">  train_l1_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_d367c_00000</td><td>TERMINATED</td><td>172.19.2.2:407 </td><td>{&#x27;hidden_dim&#x27;: _9ac0</td><td style="text-align: right;"> 0.00786079</td><td style="text-align: right;">0.000437945</td><td style="text-align: right;">    80</td><td style="text-align: right;">         310.756</td><td style="text-align: right;">    0.99097 </td><td style="text-align: right;">        0.990472</td><td style="text-align: right;">    0.0634333  </td></tr>
# <tr><td>train_model_d367c_00001</td><td>TERMINATED</td><td>172.19.2.2:553 </td><td>{&#x27;hidden_dim&#x27;: _1c80</td><td style="text-align: right;"> 0.0446133 </td><td style="text-align: right;">0.00272249 </td><td style="text-align: right;">    80</td><td style="text-align: right;">         222.09 </td><td style="text-align: right;">    0.9814  </td><td style="text-align: right;">        0.9814  </td><td style="text-align: right;">    0          </td></tr>
# <tr><td>train_model_d367c_00002</td><td>TERMINATED</td><td>172.19.2.2:684 </td><td>{&#x27;hidden_dim&#x27;: _2f80</td><td style="text-align: right;"> 0.0028269 </td><td style="text-align: right;">0.0936196  </td><td style="text-align: right;">    40</td><td style="text-align: right;">         129.275</td><td style="text-align: right;">   33.1922  </td><td style="text-align: right;">       33.1774  </td><td style="text-align: right;">    5.24938    </td></tr>
# <tr><td>train_model_d367c_00003</td><td>TERMINATED</td><td>172.19.2.2:804 </td><td>{&#x27;hidden_dim&#x27;: _4500</td><td style="text-align: right;"> 0.00597965</td><td style="text-align: right;">2.5011e-05 </td><td style="text-align: right;">    80</td><td style="text-align: right;">         229.677</td><td style="text-align: right;">    0.733222</td><td style="text-align: right;">        0.560459</td><td style="text-align: right;">   28.8919     </td></tr>
# <tr><td>train_model_d367c_00012</td><td>TERMINATED</td><td>172.19.2.2:1943</td><td>{&#x27;hidden_dim&#x27;: _0bc0</td><td style="text-align: right;"> 0.0152066 </td><td style="text-align: right;">0.0100175  </td><td style="text-align: right;">    80</td><td style="text-align: right;">         230.669</td><td style="text-align: right;">    0.932393</td><td style="text-align: right;">        0.932393</td><td style="text-align: right;">    0          </td></tr>
# <tr><td>train_model_d367c_00013</td><td>TERMINATED</td><td>172.19.2.2:2074</td><td>{&#x27;hidden_dim&#x27;: _2fc0</td><td style="text-align: right;"> 0.00771507</td><td style="text-align: right;">5.81585e-05</td><td style="text-align: right;">    80</td><td style="text-align: right;">         221.252</td><td style="text-align: right;">    0.797458</td><td style="text-align: right;">        0.666566</td><td style="text-align: right;">   16.9658     </td></tr>
# <tr><td>train_model_d367c_00014</td><td>TERMINATED</td><td>172.19.2.2:2204</td><td>{&#x27;hidden_dim&#x27;: _e600</td><td style="text-align: right;"> 0.00818929</td><td style="text-align: right;">0.0189557  </td><td style="text-align:
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# (train_model pid=407) /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# (train_model pid=407)   self.pid = os.fork()
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# (train_model pid=407) RESULTS:
# (train_model pid=407) tensor(1.9815, device='cuda:0') tensor(1.0586, device='cuda:0') tensor(117.4091, device='cuda:0') 49.922382831573486
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.71it/s]
# (train_model pid=407) RESULTS:  tensor(1.9734, device='cuda:0') tensor(1.0532, device='cuda:0') tensor(117.0725, device='cuda:0') 49.92486834526062
#
# Epoch 0:   0%|          | 0/254 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 1/254 [00:16<1:11:25,  0.06it/s, v_num=0]
# Epoch 0:   1%|          | 2/254 [00:18<38:58,  0.11it/s, v_num=0]
# Epoch 0:   1%|          | 3/254 [00:20<28:09,  0.15it/s, v_num=0]
# Epoch 0:   2%|▏         | 4/254 [00:25<26:09,  0.16it/s, v_num=0]
# Epoch 0:   2%|▏         | 5/254 [00:27<22:58,  0.18it/s, v_num=0]
# Epoch 0:   2%|▏         | 6/254 [00:29<20:10,  0.20it/s, v_num=0]
# Epoch 0:   3%|▎         | 7/254 [00:37<22:06,  0.19it/s, v_num=0]
# Epoch 0:   3%|▎         | 8/254 [00:40<20:45,  0.20it/s, v_num=0]
# Epoch 0:   4%|▎         | 9/254 [00:42<19:06,  0.21it/s, v_num=0]
# Epoch 0:   4%|▍         | 10/254 [00:43<17:46,  0.23it/s, v_num=0]
# Epoch 0:   4%|▍         | 11/254 [00:55<20:18,  0.20it/s, v_num=0]
# Epoch 0:   5%|▍         | 12/254 [00:56<19:05,  0.21it/s, v_num=0]
# Epoch 0:   5%|▌         | 13/254 [00:58<18:02,  0.22it/s, v_num=0]
# Epoch 0:   6%|▌         | 14/254 [01:00<17:23,  0.23it/s, v_num=0]
# Epoch 0:   6%|▌         | 15/254 [01:07<17:55,  0.22it/s, v_num=0]
# Epoch 0:   6%|▋         | 16/254 [01:09<17:08,  0.23it/s, v_num=0]
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(_ZSt10unexpectedv+0) [0x7e6aac617303] std::unexpected()
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(__gxx_personality_v0+0x414) [0x7e6aac61d1d1] __gxx_personality_v0
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(+0x15f48) [0x7e6aac55df48] _Unwind_ForcedUnwind_Phase2
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(_Unwind_ForcedUnwind+0x74) [0x7e6aac55e2af] _Unwind_ForcedUnwind
# (train_model pid=407) /lib/x86_64-linux-gnu/libc.so.6(+0x9d446) [0x7e6aaf070446]
# (train_model pid=407) /lib/x86_64-linux-gnu/libc.so.6(pthread_exit+0x3a) [0x7e6aaf068cba] pthread_exit
# (train_model pid=407) ray::ImplicitFunc(+0xe929a) [0x5a0138e5929a] _append_preinit_entry.isra.0
# (train_model pid=407) ray::ImplicitFunc(+0x5df15) [0x5a0138dcdf15] take_gil.cold
# (train_model pid=407) ray::ImplicitFunc(PyEval_RestoreThread+0x12) [0x5a0138ecf622] PyEval_RestoreThread
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x4e4514) [0x7e680d7ee514] torch::autograd::dispatch_to()
# (train_model pid=407) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x5054e9) [0x7e680d80f4e9] torch::autograd::THPVariable_to()
# (train_model pid=407) ray::ImplicitFunc(+0x1445a6) [0x5a0138eb45a6] cfunction_call
# (train_model pid=407) ray::ImplicitFunc(PyObject_Call+0x207) [0x5a0138ec1067] PyObject_Call
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x5cd5) [0x5a0138eaa205] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x5a0138ea72b3] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x13ca) [0x5a0138ea58fa] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x5a0138ea4850] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x5a0138ea4850] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x5a0138ea4850] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x4c12) [0x5a0138ea9142] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(+0x1d6242) [0x5a0138f46242] _PyObject_VectorcallTstate.lto_priv.24
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x5a0138ea4850] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x5a0138ea72b3] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x5a0138ea72b3] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x5a0138eb4a2c] _PyFunction_Vectorcall
# (train_model pid=407) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x5a0138ea4c5c] _PyEval_EvalFrameDefault
# (train_model pid=407) ray::ImplicitFunc(+0x150804) [0x5a0138ec0804] method_vectorcall
# (train_model pid=407) ray::ImplicitFunc(+0x228372) [0x5a0138f98372] thread_run
# (train_model pid=407) ray::ImplicitFunc(+0x228324) [0x5a0138f98324] pythread_wrapper
# (train_model pid=407) /lib/x86_64-linux-gnu/libc.so.6(+0x94ac3) [0x7e6aaf067ac3]
# (train_model pid=407) /lib/x86_64-linux-gnu/libc.so.6(clone+0x44) [0x7e6aaf0f8a04] __clone
# (train_model pid=407)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# (train_model pid=553) /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# (train_model pid=553)   self.pid = os.fork()
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# (train_model pid=553) RESULTS:
# (train_model pid=553) tensor(5.8294, device='cuda:0') tensor(1.0611, device='cuda:0') tensor(106.8794, device='cuda:0') 50.20785331726074
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.70it/s]
# (train_model pid=553) RESULTS:  tensor(5.8123, device='cuda:0') tensor(1.0569, device='cuda:0') tensor(106.5934, device='cuda:0') 50.1967191696167
#
# Epoch 0:   0%|          | 0/508 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 1/508 [00:11<1:36:18,  0.09it/s, v_num=0]
# Epoch 0:   0%|          | 2/508 [00:11<49:14,  0.17it/s, v_num=0]
# Epoch 0:   1%|          | 3/508 [00:11<33:32,  0.25it/s, v_num=0]
# Epoch 0:   1%|          | 4/508 [00:20<42:10,  0.20it/s, v_num=0]
# Epoch 0:   1%|          | 5/508 [00:20<34:05,  0.25it/s, v_num=0]
# Epoch 0:   1%|          | 6/508 [00:20<28:42,  0.29it/s, v_num=0]
# Epoch 0:   1%|▏         | 7/508 [00:28<33:52,  0.25it/s, v_num=0]
# Epoch 0:   2%|▏         | 8/508 [00:28<29:50,  0.28it/s, v_num=0]
# Epoch 0:   2%|▏         | 9/508 [00:28<26:42,  0.31it/s, v_num=0]
# Epoch 0:   2%|▏         | 10/508 [00:35<29:35,  0.28it/s, v_num=0]
# (train_model pid=553) [2024-12-04 13:03:10,183 E 553 595] logging.cc:115: Stack trace:
# (train_model pid=553)  /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1033f2a) [0x7dfbd12a1f2a] ray::operator<<()
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1036f72) [0x7dfbd12a4f72] ray::TerminateHandler()
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(+0xb6502) [0x7dfbd0141502] __cxxabiv1::__terminate()
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(_ZSt10unexpectedv+0) [0x7dfbd013b303] std::unexpected()
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(__gxx_personality_v0+0x414) [0x7dfbd01411d1] __gxx_personality_v0
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(+0x15f48) [0x7dfbd0081f48] _Unwind_ForcedUnwind_Phase2
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(_Unwind_ForcedUnwind+0x74) [0x7dfbd00822af] _Unwind_ForcedUnwind
# (train_model pid=553) /lib/x86_64-linux-gnu/libc.so.6(+0x9d446) [0x7dfbd2b94446]
# (train_model pid=553) /lib/x86_64-linux-gnu/libc.so.6(pthread_exit+0x3a) [0x7dfbd2b8ccba] pthread_exit
# (train_model pid=553) ray::ImplicitFunc(+0xe929a) [0x593c0179b29a] _append_preinit_entry.isra.0
# (train_model pid=553) ray::ImplicitFunc(+0x5df15) [0x593c0170ff15] take_gil.cold
# (train_model pid=553) ray::ImplicitFunc(PyEval_RestoreThread+0x12) [0x593c01811622] PyEval_RestoreThread
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x4e4514) [0x7df9313ee514] torch::autograd::dispatch_to()
# (train_model pid=553) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x5054e9) [0x7df93140f4e9] torch::autograd::THPVariable_to()
# (train_model pid=553) ray::ImplicitFunc(+0x1445a6) [0x593c017f65a6] cfunction_call
# (train_model pid=553) ray::ImplicitFunc(PyObject_Call+0x207) [0x593c01803067] PyObject_Call
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x5cd5) [0x593c017ec205] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x593c017e92b3] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x13ca) [0x593c017e78fa] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x593c017e6850] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x593c017e6850] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x593c017e6850] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x4c12) [0x593c017eb142] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(+0x1d6242) [0x593c01888242] _PyObject_VectorcallTstate.lto_priv.24
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x593c017e6850] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x593c017e92b3] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x593c017e92b3] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x593c017f6a2c] _PyFunction_Vectorcall
# (train_model pid=553) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x593c017e6c5c] _PyEval_EvalFrameDefault
# (train_model pid=553) ray::ImplicitFunc(+0x150804) [0x593c01802804] method_vectorcall
# (train_model pid=553) ray::ImplicitFunc(+0x228372) [0x593c018da372] thread_run
# (train_model pid=553) ray::ImplicitFunc(+0x228324) [0x593c018da324] pythread_wrapper
# (train_model pid=553) /lib/x86_64-linux-gnu/libc.so.6(+0x94ac3) [0x7dfbd2b8bac3]
# (train_model pid=553) /lib/x86_64-linux-gnu/libc.so.6(clone+0x44) [0x7dfbd2c1ca04] __clone
# (train_model pid=553)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# (train_model pid=684) /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# (train_model pid=684)   self.pid = os.fork()
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# (train_model pid=684) RESULTS:  tensor(1.2923, device='cuda:0') tensor(1.0576, device='cuda:0')
# (train_model pid=684) tensor(83.0388, device='cuda:0') 49.97713565826416
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.18it/s]
# (train_model pid=684) RESULTS:  tensor(1.2868, device='cuda:0') tensor(1.0526, device='cuda:0') tensor(82.8440, device='cuda:0') 49.971458315849304
#
# Epoch 0:   0%|          | 0/508 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 1/508 [00:10<1:26:45,  0.10it/s]
# Epoch 0:   0%|          | 1/508 [00:10<1:26:46,  0.10it/s, v_num=0]
# Epoch 0:   0%|          | 2/508 [00:10<45:07,  0.19it/s, v_num=0]
# Epoch 0:   1%|          | 3/508 [00:11<31:15,  0.27it/s, v_num=0]
# Epoch 0:   1%|          | 4/508 [00:19<40:10,  0.21it/s, v_num=0]
# Epoch 0:   1%|          | 5/508 [00:19<32:48,  0.26it/s, v_num=0]
# (train_model pid=684) [2024-12-04 13:05:26,843 E 684 726] logging.cc:115: Stack trace:
# (train_model pid=684)  /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1033f2a) [0x7dc9b9a19f2a] ray::operator<<()
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1036f72) [0x7dc9b9a1cf72] ray::TerminateHandler()
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(+0xb6502) [0x7dc9b88b9502] __cxxabiv1::__terminate()
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(_ZSt10unexpectedv+0) [0x7dc9b88b3303] std::unexpected()
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(__gxx_personality_v0+0x414) [0x7dc9b88b91d1] __gxx_personality_v0
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(+0x15f48) [0x7dc9b87f9f48] _Unwind_ForcedUnwind_Phase2
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(_Unwind_ForcedUnwind+0x74) [0x7dc9b87fa2af] _Unwind_ForcedUnwind
# (train_model pid=684) /lib/x86_64-linux-gnu/libc.so.6(+0x9d446) [0x7dc9bb30c446]
# (train_model pid=684) /lib/x86_64-linux-gnu/libc.so.6(pthread_exit+0x3a) [0x7dc9bb304cba] pthread_exit
# (train_model pid=684) ray::ImplicitFunc(+0xe929a) [0x55572713c29a] _append_preinit_entry.isra.0
# (train_model pid=684) ray::ImplicitFunc(+0x5df15) [0x5557270b0f15] take_gil.cold
# (train_model pid=684) ray::ImplicitFunc(PyEval_RestoreThread+0x12) [0x5557271b2622] PyEval_RestoreThread
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x4e4514) [0x7dc7199ee514] torch::autograd::dispatch_to()
# (train_model pid=684) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x5054e9) [0x7dc719a0f4e9] torch::autograd::THPVariable_to()
# (train_model pid=684) ray::ImplicitFunc(+0x1445a6) [0x5557271975a6] cfunction_call
# (train_model pid=684) ray::ImplicitFunc(PyObject_Call+0x207) [0x5557271a4067] PyObject_Call
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x5cd5) [0x55572718d205] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x55572718a2b3] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x13ca) [0x5557271888fa] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x555727187850] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x555727187850] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x555727187850] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x4c12) [0x55572718c142] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(+0x1d6242) [0x555727229242] _PyObject_VectorcallTstate.lto_priv.24
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x555727187850] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x55572718a2b3] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x55572718a2b3] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x555727197a2c] _PyFunction_Vectorcall
# (train_model pid=684) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x555727187c5c] _PyEval_EvalFrameDefault
# (train_model pid=684) ray::ImplicitFunc(+0x150804) [0x5557271a3804] method_vectorcall
# (train_model pid=684) ray::ImplicitFunc(+0x228372) [0x55572727b372] thread_run
# (train_model pid=684) ray::ImplicitFunc(+0x228324) [0x55572727b324] pythread_wrapper
# (train_model pid=684) /lib/x86_64-linux-gnu/libc.so.6(+0x94ac3) [0x7dc9bb303ac3]
# (train_model pid=684) /lib/x86_64-linux-gnu/libc.so.6(clone+0x44) [0x7dc9bb394a04] __clone
# (train_model pid=684)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# (train_model pid=804) /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=3` in the `DataLoader` to improve performance.
# (train_model pid=804) /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# (train_model pid=804)   self.pid = os.fork()
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# (train_model pid=804) RESULTS:
# (train_model pid=804) tensor(1.4045, device='cuda:0') tensor(1.0530, device='cuda:0') tensor(58.7711, device='cuda:0') 49.997785687446594
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.37it/s]
# (train_model pid=804) RESULTS:  tensor(1.3995, device='cuda:0') tensor(1.0489, device='cuda:0') tensor(58.6342, device='cuda:0') 49.98928904533386
#
# Epoch 0:   0%|          | 0/508 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 1/508 [00:10<1:27:06,  0.10it/s, v_num=0]
# Epoch 0:   0%|          | 2/508 [00:11<47:04,  0.18it/s, v_num=0]
# Epoch 0:   1%|          | 3/508 [00:12<33:40,  0.25it/s, v_num=0]
# Epoch 0:   1%|          | 4/508 [00:19<40:59,  0.20it/s, v_num=0]
# Epoch 0:   1%|          | 5/508 [00:20<34:05,  0.25it/s, v_num=0]
# Epoch 0:   1%|          | 6/508 [00:21<29:30,  0.28it/s, v_num=0]
# Epoch 0:   1%|▏         | 7/508 [00:28<33:29,  0.25it/s, v_num=0]
INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/kaggle/working/results/hyperparameter_search' in 0.0314s.
# 2024-12-04 14:04:05,888	INFO tune.py:1041 -- Total run time: 4208.28 seconds (4202.26 seconds for the tuning loop).
# Best Hyperparameters Found:
# {'HB': {'hidden_dim': 65536, 'batch_size': 4096}, 'lr': 0.00043794538106065907, 'l1_lambda': 0.00786079101749009}
# (train_model pid=2843) [2024-12-04 14:04:06,432 E 2843 2885] logging.cc:115: Stack trace:
# (train_model pid=2843)  /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1033f2a) [0x79a27933ff2a] ray::operator<<()
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/_raylet.so(+0x1036f72) [0x79a279342f72] ray::TerminateHandler()
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(+0xb6502) [0x79a2781df502] __cxxabiv1::__terminate()
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(_ZSt10unexpectedv+0) [0x79a2781d9303] std::unexpected()
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/../../../libstdc++.so.6(__gxx_personality_v0+0x414) [0x79a2781df1d1] __gxx_personality_v0
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(+0x15f48) [0x79a27811ff48] _Unwind_ForcedUnwind_Phase2
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/ray/../../../libgcc_s.so.1(_Unwind_ForcedUnwind+0x74) [0x79a2781202af] _Unwind_ForcedUnwind
# (train_model pid=2843) /lib/x86_64-linux-gnu/libc.so.6(+0x9d446) [0x79a27ac32446]
# (train_model pid=2843) /lib/x86_64-linux-gnu/libc.so.6(pthread_exit+0x3a) [0x79a27ac2acba] pthread_exit
# (train_model pid=2843) ray::ImplicitFunc(+0xe929a) [0x556a2b91b29a] _append_preinit_entry.isra.0
# (train_model pid=2843) ray::ImplicitFunc(+0x5df15) [0x556a2b88ff15] take_gil.cold
# (train_model pid=2843) ray::ImplicitFunc(PyEval_RestoreThread+0x12) [0x556a2b991622] PyEval_RestoreThread
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x4e4514) [0x799fd93ee514] torch::autograd::dispatch_to()
# (train_model pid=2843) /opt/conda/lib/python3.10/site-packages/torch/lib/libtorch_python.so(+0x5054e9) [0x799fd940f4e9] torch::autograd::THPVariable_to()
# (train_model pid=2843) ray::ImplicitFunc(+0x1445a6) [0x556a2b9765a6] cfunction_call
# (train_model pid=2843) ray::ImplicitFunc(PyObject_Call+0x207) [0x556a2b983067] PyObject_Call
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x5cd5) [0x556a2b96c205] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x556a2b9692b3] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x13ca) [0x556a2b9678fa] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x556a2b966850] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x556a2b966850] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x556a2b966850] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x4c12) [0x556a2b96b142] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(+0x1d6242) [0x556a2ba08242] _PyObject_VectorcallTstate.lto_priv.24
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x320) [0x556a2b966850] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x556a2b9692b3] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x2d83) [0x556a2b9692b3] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(_PyFunction_Vectorcall+0x6c) [0x556a2b976a2c] _PyFunction_Vectorcall
# (train_model pid=2843) ray::ImplicitFunc(_PyEval_EvalFrameDefault+0x72c) [0x556a2b966c5c] _PyEval_EvalFrameDefault
# (train_model pid=2843) ray::ImplicitFunc(+0x150804) [0x556a2b982804] method_vectorcall
# (train_model pid=2843) ray::ImplicitFunc(+0x228372) [0x556a2ba5a372] thread_run
# (train_model pid=2843) ray::ImplicitFunc(+0x228324) [0x556a2ba5a324] pythread_wrapper
# (train_model pid=2843) /lib/x86_64-linux-gnu/libc.so.6(+0x94ac3) [0x79a27ac29ac3]
# (train_model pid=2843) /lib/x86_64-linux-gnu/libc.so.6(clone+0x44) [0x79a27acbaa04] __clone
# (train_model pid=2843)
